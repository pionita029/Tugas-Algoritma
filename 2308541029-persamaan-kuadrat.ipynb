# %% [markdown]
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load
#
# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#
# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
#
# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))
#
# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# menentukan diskriminan
# menentukan persamaan kuadrat jika diketahui akar-akarnya
# menentukan titik puncak dan sumbu simetri
# menentukan posisi titik puncak (di kiri sumbu y, pada sumbu y (b=0), dikanan sumbu y)
# menentukan posisi titik puncak memotong sumbu y (potong sumbu y positif, potong sumbu y di titik pusat (0,0), potong sumbu y negatif)
# macam-macam akar persamaan kuadrat dilihat dari diskriminan
# penyelesaian persaman kuadrat dapat menggunakan rumus ABC
# menyusun persamaan kuadrat baru jika diketauhi akar-akarnya

# %%
print("Halo, saya Pionita. Disini saya akan membuat program mengenai persamaan kuadrat")

import sys
import math
import numpy as np
import matplotlib.pyplot as plt

print('')
print('Bentuk umum persamaan kuadrat adalah: a_29*x^2 + b_29*x + c_29 = 0')

print("Kita akan mencari koefisien dari a,b,c terlebih dahulu")
a_29 = int(input("Masukkan koefisien a_29:"))
b_29 = int(input("Masukkan koefisien b_29:"))
c_29 = int(input("Masukkan koefisien c_29:"))

print("Setelah mendapat nilai koefisien a,b,c kita akan mencari rumus diskriminan. Semangat!!")
D = b_29**2 - 4*a_29*c_29

print("Rumus diskriminanya sudah dapet nih,saatnya kita akan membuat kesimpulan dari solusi persamaan kuadrat yang telah kita ketahui")
if D<0:
    print("Jenis akar adalah imajiner")
    sys.exit(1)
elif D==0:
    x1_29 = (-b_29+math.sqrt(D) / (2*a_29))
    x2_29 = x1
    print("Jenis akarnya adalah akar kembar dan real")
else:
    x1_29 = (-b_29+math.sqrt(D)) / (2*a_29)
    x2_29 = (-b_29-math.sqrt(D)) / (2*a_29)
    print("Jenis akarnya adalah akar berbeda dan real")
    
print('')
print("penyelesaian:")
print("Sehingga persamaan dapat dibentuk sebagai berikut:((0)x^2 + (1)x + (2))".format(a_29, b_29, c_29))

#Titik potong sumbu x_29
print("Titik potong sumbu x1_29:", x1_29)
print("Titik potong sumbu x2_29:", x2_29)

#Titik potong dengan sumbu y_29
y_29 = c_29
print("Titik potong sumbu y_29:", y_29)

# Sumbu simetri x_29
x_29 = (-b_29 / (2*a_29))
print("Sumbu simetri x_29:", x_29)

#Titik puncak
xp = (x_29, (D / (2*a_29)))
print("Titik puncak:", xp)
print("Jadi akar dari persamaan kuadrat adalah " +str(x1_29)+ "dan" +str(x2_29))
print("Dengan nilai diskriminan =", D)
print("Maka akan membentuk grafik yang terbuka ke atas")

# Menggambar grafik fungsi kuadrat
# Disini kita menentukan nilai x
x_29 = np. linspace(-30, 25, 15)
y_29 = a_29*x_29**2 + b_29*x_29 + c_29

plt.plot(x_29, y_29, label=f'{a_29}x^2 + {b_29}x + {c_29} = 0', color='gray')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(color='violet', linestyle='--', linewidth=0.5)
plt.legend()
plt.xlabel('sumbu x')
plt.ylabel('sumbu y')
plt.title('Grafik Persamaan Kuadrat')
plt.show()
# Out:
# Halo, saya Pionita. Disini saya akan membuat program mengenai persamaan kuadrat
#
# Bentuk umum persamaan kuadrat adalah: a_29*x^2 + b_29*x + c_29 = 0
# Kita akan mencari koefisien dari a,b,c terlebih dahulu
# Masukkan koefisien a_29: 2
# Masukkan koefisien b_29: 1
# Masukkan koefisien c_29: -2
# Setelah mendapat nilai koefisien a,b,c kita akan mencari rumus diskriminan. Semangat!!
# Rumus diskriminanya sudah dapet nih,saatnya kita akan membuat kesimpulan dari solusi persamaan kuadrat yang telah kita ketahui
# Jenis akarnya adalah akar berbeda dan real
#
# penyelesaian:
# Sehingga persamaan dapat dibentuk sebagai berikut:((0)x^2 + (1)x + (2))
# Titik potong sumbu x1_29: 0.7807764064044151
# Titik potong sumbu x2_29: -1.2807764064044151
# Titik potong sumbu y_29: -2
# Sumbu simetri x_29: -0.25
# Titik puncak: (-0.25, 4.25)
# Jadi akar dari persamaan kuadrat adalah 0.7807764064044151dan-1.2807764064044151
# Dengan nilai diskriminan = 17
# ...

# %%
print("Halo, saya Pionita. Disini saya akan membuat program mengenai persamaan kuadrat")

import sys
import math
import numpy as np
import matplotlib.pyplot as plt

print('')
print('Bentuk umum persamaan kuadrat: a_29*x^2 + b_29*x + c_29 = 0')

a_29 = int(input("Masukkan koefisien a_29:"))
b_29 = int(input("Masukkan koefisien b_29:"))
c_29 = int(input("Masukkan koefisien c_29:"))

D = b_29**2 - 4*a_29*c_29
if D<0:
    print("Jenis akar adalah imajiner")
    sys.exit(1)
elif D==0:
    x1_29 = (-b_29+math.sqrt(D) / (2*a_29))
    x2_29 = x1
    print("Jenis akarnya adalah akar kembar dan real")
else:
    x1_29 = (-b_29+math.sqrt(D)) / (2*a_29)
    x2_29 = (-b_29-math.sqrt(D)) / (2*a_29)
    print("Jenis akarnya adalah akar berbeda dan real")
    
print('')
print("penyelesaian:")
print("Sehingga persamaan dapat dibentuk sebagai berikut:((0)x^2 + (1)x + (2))".format(a_29, b_29, c_29))

#Titik potong sumbu x_29
print("Titik potong sumbu x1_29:", x1_29)
print("Titik potong sumbu x2_29:", x2_29)

#Titik potong dengan sumbu y_29
y_29 = c_29
print("Titik potong sumbu y_29:", y_29)

# Sumbu simetri x_29
x_29 = (-b_29 / (2*a_29))
print("Sumbu simetri x_29:", x_29)

#Titik puncak
xp = (x_29, (D / (2*a_29)))
print("Titik puncak:", xp)
print("Jadi akar dari persamaan kuadrat adalah" +str(x1_29)+ "dan" +str(x2_29))
print('Dengan nilai diskriminan =', D)
print("Maka akan membentuk grafik yang terbuka ke bawah")

# Menggambar grafik fungsi kuadrat
x_29 = np. linspace(-20, 20, 15)
y_29 = a_29*x_29**2 + b_29*x_29 + c_29


plt.plot(x_29, y_29, color = "gray", label = "y_29 = a_29*x*x + b_29*x + c_29")
plt.axhline(0, color = 'orange', linewidth=0.5)
plt.axvline(0, color = 'orange', linewidth=0.5)
plt.scatter(x_29, y_29, color = "violet", label = "y_29 = a_29*x*x + b_29*x + c_29" )
plt.legend()
plt.title("Grafik Persamaan Kuadrat")
plt.grid(color='green', linestyle='--', linewidth=0.5)
plt.xlabel("Sumbu x_29")
plt.ylabel("Sumbu y_29")
plt.show()
# Out:
# Halo, saya Pionita. Disini saya akan membuat program mengenai persamaan kuadrat
#
# Bentuk umum persamaan kuadrat: a_29*x^2 + b_29*x + c_29 = 0
# Masukkan koefisien a_29: -4
# Masukkan koefisien b_29: 1
# Masukkan koefisien c_29: 6
# Jenis akarnya adalah akar berbeda dan real
#
# penyelesaian:
# Sehingga persamaan dapat dibentuk sebagai berikut:((0)x^2 + (1)x + (2))
# Titik potong sumbu x1_29: -1.106107225224513
# Titik potong sumbu x2_29: 1.356107225224513
# Titik potong sumbu y_29: 6
# Sumbu simetri x_29: 0.125
# Titik puncak: (0.125, -12.125)
# Jadi akar dari persamaan kuadrat adalah-1.106107225224513dan1.356107225224513
# Dengan nilai diskriminan = 97
# Maka akan membentuk grafik yang terbuka ke bawah
