# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import math

# Diketahui X memenuhi X^2 + X - 1 = 0
# Tentukan nilai dari n yang memenuhi X^2024 - X^2025 = (X(1 - X))^n

print("Pada kali ini kita akan mencari nilai dari n yang memenuhi X^2024 - X^2025. Tapi sebelum itu diberikan X^2 + X - 1 = 0, dimana kita akan mencari terlebih dahulu nilai X nya ")
SMP_29 = input("nilai dari X_29^2 + X_29 - 1 = 0  adalah")

# Akan dicari nilai X dengan rumus ABC (- b_29 +- math.sqrt(b_29^2 - 4*a_29*c_29) / 2*a_29)
# Menghitung nilai X dengan rumus ABC

X1_29 = (- 1 + math.sqrt(5 ) / 2)
X2_29 = (- 1 - math.sqrt(5 ) / 2)

# Memilih nilai X yang positif yaitu X1
X1_29 = (-1 + math.sqrt (5) / 2)

print("nilai dari X1_29 adalah", str(X1_29))

# Mencari nilai dari n untuk memenuhi persamaan (X**2024 - X**2025) = (X(1-X))**n
ruas_kiri_29 = float(input("nilai dari X_29**2024 *3 X_29**2 adalah"))
ruas_kanan_29 = float(input("nilai dari X_29 * X_29**2 adalah"))

# Menggunakan logaritma (log) untuk menemukan nilai n
if ruas_kiri_29 > 0 and ruas_kanan_29 > 0:
    n_29 = math.log(ruas_kiri_29) / math.log(ruas_kanan_29)
    
    print("Dengan menggunakan logaritma (log) diperoleh hasil dari n adalah:", n_29)
    
    print("Ruas kiri atau ruas kanan dari persamaan tidak valid sehingga nilai dari n salah")
    
    print("Persamaannya tidak valid karena pada log harus ada basis sedangkan pada soal tidak ada basisnya sehingga akan kita coba untuk menggunakan ln ")

# Disini kita menggunakan fungsi desimal untuk mengatasi angka yang sangat besar atau yang sangat kecil supaya tidak ada out of range
from decimal import Decimal
ruas_kiri_29 = Decimal(X1_29)**2026
ruas_kanan_29 = Decimal(X1_29)**3

# Dengan menggunakan ln akan diperoleh nilai n yang benar
if ruas_kanan_29 > 0:
    n_29 = float(ruas_kiri_29.ln() / ruas_kanan_29.ln())
    print("Dengan menggunakan ln diperoleh hasil dari n yaitu:", n_29)
    
print("Nah, jika menggunakan ln maka diperoleh hasil yang benar")
# Out:
# Pada kali ini kita akan mencari nilai dari n yang memenuhi X^2024 - X^2025. Tapi sebelum itu diberikan X^2 + X - 1 = 0, dimana kita akan mencari terlebih dahulu nilai X nya
# nilai dari X_29^2 + X_29 - 1 = 0  adalah 1 - X = X^2
# nilai dari X1_29 adalah 0.1180339887498949
# nilai dari X_29**2024 *3 X_29**2 adalah 2026
# nilai dari X_29 * X_29**2 adalah 3
# Dengan menggunakan logaritma (log) diperoleh hasil dari n adalah: 6.9303964313371695
# Ruas kiri atau ruas kanan dari persamaan tidak valid sehingga nilai dari n salah
# Persamaannya tidak valid karena pada log harus ada basis sedangkan pada soal tidak ada basisnya sehingga akan kita coba untuk menggunakan ln
# Dengan menggunakan ln diperoleh hasil dari n yaitu: 675.3333333333334
# Nah, jika menggunakan ln maka diperoleh hasil yang benar
