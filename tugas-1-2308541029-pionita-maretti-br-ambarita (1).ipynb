# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
tinggi_gedung_029= input("berapakah tinggi gedung dekanat?")
tinggi_pohon_029 = input("berapakah tinggi pohon? ")
jumlah_tinggi_029 = int(tinggi_gedung_029) + int(tinggi_pohon_029)
print("jumlah tinggi gedung dan pohon adalah " + str (jumlah_tinggi_029))
# Out:
# berapakah tinggi gedung dekanat? 1500
# berapakah tinggi pohon?  680
# jumlah tinggi gedung dan pohon adalah 2180

# %%
naskah_029 = print("Viony adalah seorang penulis")
naskah_029 = print("hari senin, kamis, sabtu Viony menyempatkan untuk menulis naskah")
jumlah_kata_hari_senin_029 = input("Berapa kata yang dapat Viony tulis pada hari senin?")
jumlah_kata_hari_kamis_029 = input("Berapa kata yang dapat Viony tulis pada hari kamis?")
jumlah_kata_hari_sabtu_029 = input("Berapa kata yang dapat Viony tulis pada hari sabtu?")
total_kata_029 = int(jumlah_kata_hari_senin_029) + int(jumlah_kata_hari_kamis_029) + int(jumlah_kata_hari_sabtu_029)
print("jumlah total kata pada hari senin, kamis, sabtu adalah" + str(total_kata_029))
# Out:
# Viony adalah seorang penulis
# hari senin, kamis, sabtu Viony menyempatkan untuk menulis naskah
# Berapa kata yang dapat Viony tulis pada hari senin? 3100
# Berapa kata yang dapat Viony tulis pada hari kamis? 2960
# Berapa kata yang dapat Viony tulis pada hari sabtu? 2990
# jumlah total kata pada hari senin, kamis, sabtu adalah9050

# %%
planet_029 = ['Merkurius', 'Venus', 'Bumi', 'Mars', 'Jupiter', 'Saturnus', 'Uranus', 'Neptunus']
for nama in planet_029:
    print (nama)
# Out:
# Merkurius
# Venus
# Bumi
# Mars
# Jupiter
# Saturnus
# Uranus
# Neptunus

# %%
bilangan_029= [2,4,6,8,10,12,6,8,14,10,18,10]
bilangan_bulat_029= []
for anggota in bilangan_029:
    if anggota not in bilangan_bulat_029:
        bilangan_bulat_029.append(anggota)
print (bilangan_bulat_029)
# Out:
# [2, 4, 6, 8, 10, 12, 14, 18]

# %%
 a_029 = 13
 b_029 = 4
 c_029 = 130
 d_029 = 3600
 e_029 = 210

print("nilai a_029 =", a_029)
print("nilai b_029 =", b_029)
print("nilai c_029 =", c_029)
print("nilai d_029 =", d_029)
print("nilai e_029 =", e_029)
# Out:
# nilai a_029 = 13
# nilai b_029 = 4
# nilai c_029 = 130
# nilai d_029 = 3600
# nilai e_029 = 210

# %%
x_029 = 16
y_029 = 21
hasil = x_029 * y_029
print(x_029,'*',y_029,'=', hasil)

hasil = x_029 - y_029
print(x_029, '-',y_029,'=', hasil)

hasil = x_029 + y_029
print(x_029, '+',y_029,'=', hasil)
# Out:
# 16 * 21 = 336
# 16 - 21 = -5
# 16 + 21 = 37

# %%
p_029 = 31
q_029 = 27
r_029 = 43 
hasil = p_029 * q_029 * r_029 - q_029 / p_029 * r_029
print(p,'*',q,'*',r,'-',q,'/',p,'*',r, '=', hasil)
# Out:
# 31 * 27 * 43 - 27 / 31 * 43 = 35953.54838709677
