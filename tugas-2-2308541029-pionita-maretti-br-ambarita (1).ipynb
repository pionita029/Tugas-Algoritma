# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#Type data 2.4

nama_29 = 'Viony March'
usia_29 = '25 tahun'
hoby_29 = 'menulis'
pekerjaan_29 = 'guru' 
print(nama_29 + " adalah seorang " + pekerjaan_29 + " memiliki hoby " + hoby_29 + " saat ini berusia " + usia_29 + " . ")
# Out:
# Viony March adalah seorang guru memiliki hoby menulis saat ini berusia 25 tahun .

# %%
#Type data 2.5

naskah_29 = 'Viony telah menerbitkan buku novelnya pada bulan Januari lalu'
print(naskah_29 [0:12])
print(naskah_29 [12:-38])
print(naskah_29 [24:-23])
print(naskah_29 [37:-12])
print(naskah_29 [48:65])
print(naskah_29 [:])
# Out:
# Viony telah
# menerbitkan
# buku novelnya
#  pada bulan
#  Januari lalu
# Viony telah menerbitkan buku novelnya pada bulan Januari lalu

# %%
#Type data 2.6

Idol_29 = 'Tulus adalah musisi Indonesia yang sangat saya suka.'
print(len(Idol_29))
Idol_29.upper()
# Out:
# 52
# 'TULUS ADALAH MUSISI INDONESIA YANG SANGAT SAYA SUKA.'

# %%
#Type data 2.6

Idol_29 = 'Tulus adalah musisi Indonesia yang sangat saya suka.'
Idol_29.lower()
# Out:
# 'tulus adalah musisi indonesia yang sangat saya suka.'

# %%
#Type data 2.6

Idol_29 = 'Tulus adalah musisi Indonesia yang sangat saya suka.'
Idol_29.find('musisi')
# Out:
# 13

# %%
#Type data 2.6

Idol_29 = 'Tulus adalah musisi Indonesia yang sangat saya suka.'
print('Indonesia' in Idol_29)
# Out:
# True

# %%
#Type 2.7
x_29 = 5
y_29 = 12
z_29 = 18

hasil = x_29 * y_29
print(x_29,'*',y_29,'=', hasil)

hasil = x_29 - y_29
print(x_29, '-',y_29,'=', hasil)

hasil = x_29 + y_29
print(x_29, '+',y_29,'=', hasil)

hasil = z_29 / x_29
print(z_29, '/', x_29, '=', hasil)

hasil = y_29 // z_29
print(y_29, '//', z_29, '=', hasil)

hasil = y_29 % x_29
print(y_29, '%', x_29,  '=', hasil)

hasil = z_29 ** x_29
print(z_29, '**', x_29, '=', hasil)
# Out:
# 5 * 12 = 60
# 5 - 12 = -7
# 5 + 12 = 17
# 18 / 5 = 3.6
# 12 // 18 = 0
# 12 % 5 = 2
# 18 ** 5 = 1889568

# %%
#Type data 2.8

u = 4 < 9
print(u)

v = 10 <= 9
print(v)

w = 8 == 16/2
print(w)

x = 18 != 38/3
print(x)
# Out:
# True
# False
# True
# True

# %%
#Type data 2.9
bunga_anggrek = 12
bunga_edelwish = 15
bunga_raflesia = 3
print(bunga_anggrek < bunga_edelwish < bunga_raflesia)
print(bunga_raflesia < bunga_anggrek < bunga_edelwish)
print(bunga_raflesia < bunga_edelwish > bunga_anggrek)
# Out:
# False
# True
# True
