# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#Type data 2.12
sistem_tata_surya_29 = ['matahari','bulan','bintang','planet','komet','galaksi','meteor','satelit']
print(sistem_tata_surya_29)
print(sistem_tata_surya_29[0])
print(sistem_tata_surya_29[1:8])
print(sistem_tata_surya_29[-1])
# Out:
# ['matahari', 'bulan', 'bintang', 'planet', 'komet', 'galaksi', 'meteor', 'satelit']
# matahari
# ['bulan', 'bintang', 'planet', 'komet', 'galaksi', 'meteor', 'satelit']
# satelit

# %%
#Type data 2.12
Nama_Hari_29 = ['senin', 'selasa', 'rabu', 'kamis', 'jumat', 'sabtu', 'minggu']
print(Nama_Hari_29)
print(Nama_Hari_29[0])
print(Nama_Hari_29[2])
print(Nama_Hari_29[-1])
print(Nama_Hari_29[0:3])
# Out:
# ['senin', 'selasa', 'rabu', 'kamis', 'jumat', 'sabtu', 'minggu']
# senin
# rabu
# minggu
# ['senin', 'selasa', 'rabu']

# %%
#Type data 2.13
penulis_29 = ['J.K Rowling', 'Andrea Hirata', 'Ananta Toer', 'Shakespear']
print(penulis_29)
penulis_29.append('Tere liye')
print(penulis_29)
penulis_29.insert(2,'Merry Riana')
print(penulis_29)
penulis_29.remove('Andrea Hirata')
print(penulis_29)
print(len(penulis_29))
# Out:
# ['J.K Rowling', 'Andrea Hirata', 'Ananta Toer', 'Shakespear']
# ['J.K Rowling', 'Andrea Hirata', 'Ananta Toer', 'Shakespear', 'Tere liye']
# ['J.K Rowling', 'Andrea Hirata', 'Merry Riana', 'Ananta Toer', 'Shakespear', 'Tere liye']
# ['J.K Rowling', 'Merry Riana', 'Ananta Toer', 'Shakespear', 'Tere liye']
# 5

# %%
#Type data 2.13
One_Direction_29 = ['Zayn', 'Harry', 'Liam', 'Nial', 'louis']
print(One_Direction_29)
One_Direction_29.remove('Zayn')
print(One_Direction_29)
One_Direction_29.remove('Harry')
print(One_Direction_29)
One_Direction_29.remove('Liam')
print(One_Direction_29)
One_Direction_29.remove('Nial')
print(One_Direction_29)
One_Direction_29.append('Zayn')
print(One_Direction_29)
One_Direction_29.insert(2,'Nial')
print(One_Direction_29)
One_Direction_29.insert(1,'Harry')
print(One_Direction_29)
One_Direction_29.insert(3,'Liam')
print(One_Direction)
# Out:
# ['Zayn', 'Harry', 'Liam', 'Nial', 'louis']
# ['Harry', 'Liam', 'Nial', 'louis']
# ['Liam', 'Nial', 'louis']
# ['Nial', 'louis']
# ['louis']
# ['louis', 'Zayn']
# ['louis', 'Zayn', 'Nial']
# ['louis', 'Harry', 'Zayn', 'Nial']
# ['louis', 'Harry', 'Zayn', 'Liam', 'Nial']

# %%
#Type data 1.14
hewan_29 = ['singa','gajah','beruang','paus','cheetah','harimau','gorila']

for jenis in hewan_29:
    print(jenis)
# Out:
# singa
# gajah
# beruang
# paus
# cheetah
# harimau
# gorila

# %%
#Type data 2.14
hewan_29 = ['singa','gajah','beruang','paus','cheetah','harimau','gorila']
i=0
while i < len(hewan_29):
        print(hewan_29[i])
        i+=1
# Out:
# singa
# gajah
# beruang
# paus
# cheetah
# harimau
# gorila
